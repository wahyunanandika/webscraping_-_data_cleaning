# %%
import pandas as pd

# %%
mvps = pd.read_csv('new_mvps_ws.csv')

# %%
mvps
# Out:
#     Unnamed: 0 Rank                   Player  Age   Tm  First  Pts Won  \
# 0            0    1              Joel Embiid   28  PHI     73      915
# 1            1    2             Nikola Jokić   27  DEN     15      674
# 2            2    3    Giannis Antetokounmpo   28  MIL     12      606
# 3            3    4             Jayson Tatum   24  BOS      0      280
# 4            4    5  Shai Gilgeous-Alexander   24  OKC      0       46
# 5            5    6         Donovan Mitchell   26  CLE      0       30
# 6            6    7         Domantas Sabonis   26  SAC      0       27
# 7            7    8              Luka Dončić   23  DAL      0       10
# 8            8    9            Stephen Curry   34  GSW      0        5
# 9            9   10             Jimmy Butler   33  MIA      0        3
# 10          10   11             De'Aaron Fox   25  SAC      0        2
# 11          11  12T            Jalen Brunson   26  NYK      0        1
# ...

# %%
mvps = mvps[["Player",'year', 'Pts Won', 'Pts Max', 'Share']]

# %%
mvps.head()
# Out:
#                     Player  year  Pts Won  Pts Max  Share
# 0              Joel Embiid  2023      915     1000  0.915
# 1             Nikola Jokić  2023      674     1000  0.674
# 2    Giannis Antetokounmpo  2023      606     1000  0.606
# 3             Jayson Tatum  2023      280     1000  0.280
# 4  Shai Gilgeous-Alexander  2023       46     1000  0.046

# %%
players = pd.read_csv('player_1991_2024.csv')

# %%
players.tail(10)
# Out:
#        Rk             Player  Age Team Pos   G  GS   MP   FG  FGA  ...  DRB  \
# 1404  726   Ryan Arcidiacono   29  NYK  PG  20   0  2.3  0.0  0.3  ...  0.4
# 1405  727    Malcolm Cazalon   22  DET  SG   1   0  3.0  0.0  0.0  ...  0.0
# 1406  728     Jalen Crutcher   24  NOP  PG   1   0  3.0  0.0  1.0  ...  0.0
# 1407  729        Andrew Funk   24  CHI  SG   5   0  2.6  0.0  0.8  ...  0.0
# 1408  730       Kaiser Gates   27  NOP  SF   1   0  7.0  0.0  4.0  ...  1.0
# 1409  731        Danny Green   36  PHI  SG   2   0  9.0  0.0  1.0  ...  1.0
# 1410  732     Ron Harper Jr.   23  TOR  PF   1   0  4.0  0.0  0.0  ...  0.0
# 1411  733     Justin Jackson   28  MIN  SF   2   0  0.5  0.0  0.0  ...  0.0
# 1412  734  Dmytro Skapintsev   25  NYK   C   2   0  1.0  0.0  0.5  ...  0.0
# 1413  735      Javonte Smart   24  PHI  PG   1   0  1.0  0.0  0.0  ...  0.0
#
#       TRB  AST  STL  BLK  TOV   PF  PTS  Awards  year
# 1404  0.4  0.2  0.1  0.0  0.1  0.3  0.0     NaN  2024
# ...

# %%
players.columns
# Out:
# Index(['Rk', 'Player', 'Age', 'Team', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
#        'Awards', 'year'],
#       dtype='object')

# %%
# players.columns = players.columns.str.replace(r'\.33', '', regex=True)

# # Check the result
# print(players.columns)

# %%
players.head()
# Out:
#    Rk                   Player  Age Team Pos   G  GS    MP    FG   FGA  ...  \
# 0   1              Joel Embiid   28  PHI   C  66  66  34.6  11.0  20.1  ...
# 1   2              Luka Dončić   23  DAL  PG  66  66  36.2  10.9  22.0  ...
# 2   3           Damian Lillard   32  POR  PG  58  58  36.3   9.6  20.7  ...
# 3   4  Shai Gilgeous-Alexander   24  OKC  PG  68  68  35.5  10.4  20.3  ...
# 4   5    Giannis Antetokounmpo   28  MIL  PF  63  63  32.1  11.2  20.3  ...
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS                       Awards  year
# 0  8.4  10.2  4.2  1.0  1.7  3.4  3.1  33.1  MVP-1,DPOY-9,CPOY-5,AS,NBA1  2023
# 1  7.8   8.6  8.0  1.4  0.5  3.6  2.5  32.4         MVP-8,CPOY-8,AS,NBA1  2023
# 2  4.0   4.8  7.3  0.9  0.3  3.3  1.9  32.2              CPOY-10,AS,NBA3  2023
# 3  4.0   4.8  5.5  1.6  1.0  2.8  2.8  31.4         MVP-5,CPOY-7,AS,NBA1  2023
# 4  9.6  11.8  5.7  0.8  0.8  3.9  3.1  31.1         MVP-3,DPOY-6,AS,NBA1  2023
#
# [5 rows x 32 columns]

# %%
del players['Rk']

# %%
del players['Awards']

# %%
players.rename(columns={'Team':'Tm'},inplace=True)

# %%
players.head()
# Out:
#                     Player  Age   Tm Pos   G  GS    MP    FG   FGA    FG%  \
# 0              Joel Embiid   28  PHI   C  66  66  34.6  11.0  20.1  0.548
# 1              Luka Dončić   23  DAL  PG  66  66  36.2  10.9  22.0  0.496
# 2           Damian Lillard   32  POR  PG  58  58  36.3   9.6  20.7  0.463
# 3  Shai Gilgeous-Alexander   24  OKC  PG  68  68  35.5  10.4  20.3  0.510
# 4    Giannis Antetokounmpo   28  MIL  PF  63  63  32.1  11.2  20.3  0.553
#
#    ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  year
# 0  ...  1.7  8.4  10.2  4.2  1.0  1.7  3.4  3.1  33.1  2023
# 1  ...  0.8  7.8   8.6  8.0  1.4  0.5  3.6  2.5  32.4  2023
# 2  ...  0.8  4.0   4.8  7.3  0.9  0.3  3.3  1.9  32.2  2023
# 3  ...  0.9  4.0   4.8  5.5  1.6  1.0  2.8  2.8  31.4  2023
# 4  ...  2.2  9.6  11.8  5.7  0.8  0.8  3.9  3.1  31.1  2023
#
# [5 rows x 30 columns]

# %%
players.head()
# Out:
#                     Player   Age   Tm Pos     G    GS    MP    FG   FGA  \
# 0              Joel Embiid  28.0  PHI   C  66.0  66.0  34.6  11.0  20.1
# 1              Luka Dončić  23.0  DAL  PG  66.0  66.0  36.2  10.9  22.0
# 2           Damian Lillard  32.0  POR  PG  58.0  58.0  36.3   9.6  20.7
# 3  Shai Gilgeous-Alexander  24.0  OKC  PG  68.0  68.0  35.5  10.4  20.3
# 4    Giannis Antetokounmpo  28.0  MIL  PF  63.0  63.0  32.1  11.2  20.3
#
#      FG%  ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  year
# 0  0.548  ...  1.7  8.4  10.2  4.2  1.0  1.7  3.4  3.1  33.1  2023
# 1  0.496  ...  0.8  7.8   8.6  8.0  1.4  0.5  3.6  2.5  32.4  2023
# 2  0.463  ...  0.8  4.0   4.8  7.3  0.9  0.3  3.3  1.9  32.2  2023
# 3  0.510  ...  0.9  4.0   4.8  5.5  1.6  1.0  2.8  2.8  31.4  2023
# 4  0.553  ...  2.2  9.6  11.8  5.7  0.8  0.8  3.9  3.1  31.1  2023
#
# [5 rows x 30 columns]

# %%
players['Player'].head(50)
# Out:
# 0                 Joel Embiid
# 1                 Luka Dončić
# 2              Damian Lillard
# 3     Shai Gilgeous-Alexander
# 4       Giannis Antetokounmpo
# 5                Jayson Tatum
# 6               Stephen Curry
# 7                Kevin Durant
# 8                Kevin Durant
# 9                Kevin Durant
# 10               LeBron James
# 11           Donovan Mitchell
# 12               Devin Booker
# 13               Kyrie Irving
# 14               Kyrie Irving
# 15               Kyrie Irving
# 16               Jaylen Brown
# 17                  Ja Morant
# 18                 Trae Young
# 19            Zion Williamson
# 20              Anthony Davis
# 21            Lauri Markkanen
# 22              Julius Randle
# 23               De'Aaron Fox
# 24                Zach LaVine
# 25             Brandon Ingram
# 26            Anthony Edwards
# 27              DeMar DeRozan
# 28               Nikola Jokić
# 29              Pascal Siakam
# 30              Jalen Brunson
# ...

# %%
players['Player'].head(50)
# Out:
# 0         Alaa Abdelnaby
# 1     Mahmoud Abdul-Rauf
# 2             Mark Acres
# 3          Michael Adams
# 4           Mark Aguirre
# 5            Danny Ainge
# 6            Mark Alarie
# 7           Steve Alford
# 8          Greg Anderson
# 9          Greg Anderson
# 10         Greg Anderson
# 11         Greg Anderson
# 12         Nick Anderson
# 13          Ron Anderson
# 14       Willie Anderson
# 15        Michael Ansley
# 16        B.J. Armstrong
# 17         Vincent Askew
# 18          Keith Askins
# 19         MiloÅ¡ BabiÄ
# 20          Thurl Bailey
# 21           Cedric Ball
# 22         Ken Bannister
# 23                Player
# 24      Charles Barkley*
# 25           Dana Barros
# 26           John Battle
# 27          Kenny Battle
# 28          Kenny Battle
# 29          Kenny Battle
# 30       William Bedford
# 31       Benoit Benjamin
# 32       Benoit Benjamin
# 33       Benoit Benjamin
# 34       Winston Bennett
# 35           Larry Bird*
# 36      Rolando Blackman
# ...

# %%
players['Player'] = players['Player'].str.replace('*', "", regex=False)

# %%
players['Player'] = players['Player'].str.replace('*', "", regex=False)

# %%
players.head(50)
# Out:
#                      Player  Age   Tm Pos   G  GS    MP    FG   FGA    FG%  \
# 0               Joel Embiid   28  PHI   C  66  66  34.6  11.0  20.1  0.548
# 1               Luka Dončić   23  DAL  PG  66  66  36.2  10.9  22.0  0.496
# 2            Damian Lillard   32  POR  PG  58  58  36.3   9.6  20.7  0.463
# 3   Shai Gilgeous-Alexander   24  OKC  PG  68  68  35.5  10.4  20.3  0.510
# 4     Giannis Antetokounmpo   28  MIL  PF  63  63  32.1  11.2  20.3  0.553
# 5              Jayson Tatum   24  BOS  SF  74  74  36.9   9.8  21.1  0.466
# 6             Stephen Curry   34  GSW  PG  56  56  34.7  10.0  20.2  0.493
# 7              Kevin Durant   34  2TM  PF  47  47  35.6  10.3  18.3  0.560
# 8              Kevin Durant   34  BRK  PF  39  39  36.0  10.5  18.8  0.559
# 9              Kevin Durant   34  PHO  PF   8   8  33.6   9.1  16.0  0.570
# 10             LeBron James   38  LAL  PF  55  54  35.5  11.1  22.2  0.500
# ...

# %%
players.head(50)
# Out:
#                 Player  Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0       Alaa Abdelnaby   PF   22  POR  43   0   6.7  1.3   2.7   .474  ...
# 1   Mahmoud Abdul-Rauf   PG   21  DEN  67  19  22.5  6.2  15.1   .413  ...
# 2           Mark Acres    C   28  ORL  68   0  19.3  1.6   3.1   .509  ...
# 3        Michael Adams   PG   28  DEN  66  66  35.5  8.5  21.5   .394  ...
# 4         Mark Aguirre   SF   31  DET  78  13  25.7  5.4  11.7   .462  ...
# 5          Danny Ainge   SG   31  POR  80   0  21.4  4.2   8.9   .472  ...
# 6          Mark Alarie   PF   27  WSB  42   1  14.0  2.4   5.4   .440  ...
# 7         Steve Alford   PG   26  DAL  34   0   6.9  1.7   3.4   .504  ...
# 8        Greg Anderson   PF   26  TOT  68   2  13.6  1.7   4.0   .430  ...
# 9        Greg Anderson   PF   26  MIL  26   0   9.5  1.0   2.8   .370  ...
# 10       Greg Anderson   PF   26  NJN   1   0  18.0  4.0   4.0  1.000  ...
# ...

# %%
players.groupby(['Player', 'year'])

# %%
players.groupby(['Player', 'year'])

# %%
def single_row(df):
    ''' 
    check if there are more than 1 name and stat in data frame
    if there is its gonna return the last team he played
    '''
    if df.shape[0] == 1:
        return df
    else:
        row = df[df['Tm'].str.contains(r'TOT|TM', na=False, case=False)]
        row['Tm'] = df.iloc[-1,:]['Tm']
        return row
    

players = players.groupby(['Player', 'year']).apply(single_row)
# Out:
# C:\Users\Wahyunan\AppData\Local\Temp\ipykernel_26064\2000890701.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   players = players.groupby(['Player', 'year']).apply(single_row)

# %%
players.head(20)
# Out:
#                                         Player  Age   Tm Pos   G  GS    MP  \
# Player            year
# A.J. Green        2023 496          A.J. Green   23  MIL  SG  35   1   9.9
#                   2024 1151         A.J. Green   24  MIL  SG  56   0  11.0
# A.J. Lawson       2023 540         A.J. Lawson   22  DAL  SG  15   0   7.2
#                   2024 1262        A.J. Lawson   23  DAL  SG  42   0   7.4
# AJ Griffin        2023 264          AJ Griffin   19  ATL  SF  72  12  19.5
#                   2024 1305         AJ Griffin   20  ATL  SF  20   0   8.6
# Aaron Gordon      2023 91         Aaron Gordon   27  DEN  PF  68  68  30.2
#                   2024 801        Aaron Gordon   28  DEN  PF  73  73  31.5
# Aaron Holiday     2023 528       Aaron Holiday   26  ATL  PG  63   6  13.4
#                   2024 1018      Aaron Holiday   27  HOU  PG  78   1  16.3
# Aaron Nesmith     2023 208       Aaron Nesmith   23  IND  SF  73  60  24.9
# ...

# %%
players.head(20)
# Out:
#                                  Player Pos Age   Tm   G  GS    MP   FG   FGA  \
# Player        year
# A.C. Green    1991 165       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6
#               1992 635       A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8
#               1993 1095      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6
#               1994 1583      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3
#               1995 2072      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5
#               1996 2569      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4
#               1997 3145      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8
#               1998 3733      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5
#               1999 4292      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1
#               2000 4821      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7
#               2001 5341      A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0
# ...

# %%
players.index = players.index.droplevel()

# %%
players.index = players.index.droplevel()

# %%
players.head()
# Out:
#            Player  Age   Tm Pos   G  GS    MP   FG  FGA    FG%  ...  ORB  DRB  \
# 496    A.J. Green   23  MIL  SG  35   1   9.9  1.5  3.6  0.424  ...  0.2  1.1
# 1151   A.J. Green   24  MIL  SG  56   0  11.0  1.5  3.5  0.423  ...  0.2  1.0
# 540   A.J. Lawson   22  DAL  SG  15   0   7.2  1.5  2.9  0.500  ...  0.4  1.0
# 1262  A.J. Lawson   23  DAL  SG  42   0   7.4  1.3  2.9  0.446  ...  0.3  0.9
# 264    AJ Griffin   19  ATL  SF  72  12  19.5  3.4  7.4  0.465  ...  0.5  1.6
#
#       TRB  AST  STL  BLK  TOV   PF  PTS  year
# 496   1.3  0.6  0.2  0.0  0.3  0.9  4.4  2023
# 1151  1.1  0.5  0.2  0.1  0.2  0.9  4.5  2024
# 540   1.4  0.1  0.1  0.0  0.2  0.7  3.7  2023
# 1262  1.2  0.5  0.2  0.1  0.3  0.5  3.2  2024
# 264   2.1  1.0  0.6  0.2  0.6  1.2  8.9  2023
#
# [5 rows x 30 columns]

# %%
players.head(20)
# Out:
#               Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 165       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  2.5
# 635       A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  3.7
# 1095      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  3.5
# 1583      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  3.4
# 2072      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  2.4
# 2569      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4  .484  ...  2.0
# 3145      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8  .483  ...  2.7
# 3733      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5  .453  ...  2.7
# 4292      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1  .422  ...  1.6
# 4821      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7  .447  ...  2.0
# 5341      A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0  .444  ...  1.3
# ...

# %%
players[players['Player'] == 'Greg Anderson']
# Out:
#              Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 8     Greg Anderson  PF  26  DEN  68   2  13.6  1.7   4.0  .430  ...  1.4
# 468   Greg Anderson  PF  27  DEN  82  82  34.1  4.7  10.4  .456  ...  4.1
# 1415  Greg Anderson  PF  29  DET  77  47  21.1  2.6   4.8  .543  ...  2.4
# 1915  Greg Anderson  PF  30  ATL  51   0  12.2  1.1   2.0  .548  ...  1.2
# 2386  Greg Anderson  PF  31  SAS  46   7   7.5  0.5   1.0  .511  ...  0.6
# 2954  Greg Anderson   C  32  SAS  82  48  20.2  1.6   3.2  .496  ...  1.9
# 3548  Greg Anderson   C  33  ATL  50   0   8.0  0.7   1.6  .444  ...  0.8
#
#       DRB   TRB  AST  STL  BLK  TOV   PF   PTS  year
# 8     3.3   4.7  0.2  0.5  0.7  1.2  2.1   4.3  1991
# 468   7.4  11.5  1.0  1.1  0.8  2.5  3.2  11.5  1992
# 1415  5.0   7.4  0.7  0.7  0.9  1.2  3.0   6.4  1994
# 1915  2.5   3.7  0.3  0.5  0.6  0.6  2.0   2.9  1995
# 2386  1.5   2.2  0.2  0.2  0.5  0.5  1.4   1.2  1996
# 2954  3.5   5.5  0.4  0.8  0.8  0.9  2.7   3.9  1997
# ...

# %%
combined = players.merge(mvps, how='outer', on=['Player', 'year'])

# %%
# merging a player using outer join (since mvp df only have nominates mvp not all players) with reference the name of player and year
combined = players.merge(mvps, how='outer', on=['Player', 'year'])

# %%
combined.head(20)
# Out:
#                Player  Age   Tm Pos   G  GS    MP   FG   FGA    FG%  ...  AST  \
# 0          A.J. Green   23  MIL  SG  35   1   9.9  1.5   3.6  0.424  ...  0.6
# 1          A.J. Green   24  MIL  SG  56   0  11.0  1.5   3.5  0.423  ...  0.5
# 2         A.J. Lawson   22  DAL  SG  15   0   7.2  1.5   2.9  0.500  ...  0.1
# 3         A.J. Lawson   23  DAL  SG  42   0   7.4  1.3   2.9  0.446  ...  0.5
# 4          AJ Griffin   19  ATL  SF  72  12  19.5  3.4   7.4  0.465  ...  1.0
# 5          AJ Griffin   20  ATL  SF  20   0   8.6  0.9   3.1  0.290  ...  0.3
# 6        Aaron Gordon   27  DEN  PF  68  68  30.2  6.3  11.2  0.564  ...  3.0
# 7        Aaron Gordon   28  DEN  PF  73  73  31.5  5.5   9.8  0.556  ...  3.5
# 8       Aaron Holiday   26  ATL  PG  63   6  13.4  1.5   3.5  0.418  ...  1.4
# 9       Aaron Holiday   27  HOU  PG  78   1  16.3  2.4   5.3  0.446  ...  1.8
# 10      Aaron Nesmith   23  IND  SF  73  60  24.9  3.5   8.1  0.427  ...  1.3
# ...

# %%
combined.head(20)
# Out:
#            Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  STL  \
# 0      A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9  0.7
# 1      A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4  1.1
# 2      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4  1.1
# 3      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7  0.9
# 4      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  1.5  0.7
# 5      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4  .484  ...  0.9  0.5
# 6      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8  .483  ...  0.8  0.8
# 7      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5  .453  ...  1.5  1.0
# 8      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1  .422  ...  0.5  0.6
# 9      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7  .447  ...  1.0  0.6
# 10     A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0  .444  ...  0.5  0.4
# ...

# %%
combined[combined['Pts Won'] > 0]
# Out:
#                       Player  Age   Tm Pos   G  GS    MP    FG   FGA    FG%  \
# 53           Anthony Edwards   22  MIN  SG  79  78  35.1   9.1  19.7  0.461
# 229             De'Aaron Fox   25  SAC  PG  73  73  33.4   9.3  18.2  0.512
# 278         Domantas Sabonis   26  SAC   C  79  79  34.6   7.3  11.9  0.615
# 279         Domantas Sabonis   27  SAC   C  82  82  35.7   7.7  13.0  0.594
# 282         Donovan Mitchell   26  CLE  SG  68  68  35.8  10.0  20.6  0.484
# 350    Giannis Antetokounmpo   28  MIL  PF  63  63  32.1  11.2  20.3  0.553
# 351    Giannis Antetokounmpo   29  MIL  PF  73  73  35.2  11.5  18.8  0.611
# 409                Ja Morant   23  MEM  PG  61  59  31.9   9.3  19.9  0.466
# 441            Jalen Brunson   26  NYK  PG  68  68  35.0   8.6  17.6  0.491
# 442            Jalen Brunson   27  NYK  PG  77  77  35.4  10.3  21.4  0.479
# 506             Jayson Tatum   24  BOS  SF  74  74  36.9   9.8  21.1  0.466
# ...

# %%
combined[combined['Pts Won'] > 0]
# Out:
#               Player    Pos Age   Tm   G  GS    MP    FG   FGA   FG%  ...  \
# 217     Al Jefferson      C  29  CHA  73  73  35.0   9.6  18.8  .509  ...
# 376    Allen Iverson     PG  21  PHI  76  74  40.1   8.2  19.8  .416  ...
# 378    Allen Iverson     SG  23  PHI  48  48  41.5   9.1  22.0  .412  ...
# 379    Allen Iverson     SG  24  PHI  70  70  40.8  10.4  24.8  .421  ...
# 380    Allen Iverson     SG  25  PHI  71  71  42.0  10.7  25.5  .420  ...
# ...              ...    ...  ..  ...  ..  ..   ...   ...   ...   ...  ...
# 15245   Vince Carter     SF  23  TOR  82  82  38.1   9.6  20.7  .465  ...
# 15246   Vince Carter     SF  24  TOR  75  75  39.7  10.2  22.1  .460  ...
# 15250   Vince Carter  SF-SG  28  NJN  77  76  36.7   9.0  20.0  .452  ...
# 15647       Yao Ming      C  23  HOU  82  82  32.8   6.5  12.5  .522  ...
# 15652       Yao Ming      C  28  HOU  77  77  33.6   7.4  13.4  .548  ...
#
#        AST  STL  BLK  TOV   PF   PTS  year Pts Won Pts Max  Share
# ...

# %%
print(combined.columns)
# Out:
# Index(['Player', 'Age', 'Tm', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year',
#        'Pts Won', 'Pts Max', 'Share'],
#       dtype='object')

# %%
print(combined.columns)
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year',
#        'Pts Won', 'Pts Max', 'Share'],
#       dtype='object')

# %%
combined['Pts Won'] = combined['Pts Won'].fillna(0)

# %%
combined['Pts Max'] = combined['Pts Max'].fillna(0)

# %%
combined['Share'] = combined['Share'].fillna(0)

# %%
# columns_to_fill = ['Pts Won', 'Pts Max', 'Share']

# for column in columns_to_fill:
#     mode_value = combined[column].mode().values[0]
#     combined[column].fillna(value=mode_value, inplace=True)

# %%
# fillna NaN with 0

# combined[['Pts Won', 'Pts Max', 'Share']].fillna(0, inplace=True)

# %%
combined.head(20)
# Out:
#                Player  Age   Tm Pos   G  GS    MP   FG   FGA    FG%  ...  AST  \
# 0          A.J. Green   23  MIL  SG  35   1   9.9  1.5   3.6  0.424  ...  0.6
# 1          A.J. Green   24  MIL  SG  56   0  11.0  1.5   3.5  0.423  ...  0.5
# 2         A.J. Lawson   22  DAL  SG  15   0   7.2  1.5   2.9  0.500  ...  0.1
# 3         A.J. Lawson   23  DAL  SG  42   0   7.4  1.3   2.9  0.446  ...  0.5
# 4          AJ Griffin   19  ATL  SF  72  12  19.5  3.4   7.4  0.465  ...  1.0
# 5          AJ Griffin   20  ATL  SF  20   0   8.6  0.9   3.1  0.290  ...  0.3
# 6        Aaron Gordon   27  DEN  PF  68  68  30.2  6.3  11.2  0.564  ...  3.0
# 7        Aaron Gordon   28  DEN  PF  73  73  31.5  5.5   9.8  0.556  ...  3.5
# 8       Aaron Holiday   26  ATL  PG  63   6  13.4  1.5   3.5  0.418  ...  1.4
# 9       Aaron Holiday   27  HOU  PG  78   1  16.3  2.4   5.3  0.446  ...  1.8
# 10      Aaron Nesmith   23  IND  SF  73  60  24.9  3.5   8.1  0.427  ...  1.3
# ...

# %%
combined.head(20)
# Out:
#            Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  STL  \
# 0      A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9  0.7
# 1      A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4  1.1
# 2      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4  1.1
# 3      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7  0.9
# 4      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  1.5  0.7
# 5      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4  .484  ...  0.9  0.5
# 6      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8  .483  ...  0.8  0.8
# 7      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5  .453  ...  1.5  1.0
# 8      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1  .422  ...  0.5  0.6
# 9      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7  .447  ...  1.0  0.6
# 10     A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0  .444  ...  0.5  0.4
# ...

# %%
teams = pd.read_csv('all_teams.csv')

# %%
teams
# Out:
#     Unnamed: 0   W   L   W/L%    GB   PS/G   PA/G    SRS  year  \
# 0            1  57  25  0.695     —  117.9  111.4   6.38  2023
# 1            2  54  28  0.659   3.0  115.2  110.9   4.37  2023
# 2            3  47  35  0.573  10.0  116.0  113.1   2.99  2023
# 3            4  45  37  0.549  12.0  113.4  112.5   1.03  2023
# 4            5  41  41  0.500  16.0  112.9  111.4   1.59  2023
# 5            7  58  24  0.707     —  116.9  113.3   3.61  2023
# 6            8  51  31  0.622   7.0  112.3  106.9   5.23  2023
# 7            9  40  42  0.488  18.0  113.1  111.8   1.37  2023
# 8           10  35  47  0.427  23.0  116.3  119.5  -2.91  2023
# 9           11  17  65  0.207  41.0  110.3  118.5  -7.73  2023
# 10          13  44  38  0.537     —  109.5  109.8  -0.13  2023
# 11          14  41  41  0.500   3.0  118.4  118.1   0.32  2023
# 12          15  35  47  0.427   9.0  113.2  114.4  -1.06  2023
# 13          16  34  48  0.415  10.0  111.4  114.0  -2.39  2023
# ...

# %%
teams
# Out:
#      Unnamed: 0   W   L   W/L%    GB   PS/G   PA/G   SRS  year  \
# 0             1  56  26  0.683     —  111.5  105.7  5.22  1991
# 1             2  44  38  0.537  12.0  105.4  105.6 -0.39  1991
# 2             3  39  43  0.476  17.0  103.1  103.3 -0.43  1991
# 3             4  30  52  0.366  26.0  101.4  106.4 -4.84  1991
# 4             5  26  56  0.317  30.0  102.9  107.5 -4.53  1991
# ..          ...  ..  ..    ...   ...    ...    ...   ...   ...
# 991          13  50  32  0.610     —  117.9  115.6  2.30  2024
# 992          14  49  33  0.598   1.0  115.1  110.7  4.46  2024
# 993          15  41  41  0.500   9.0  114.3  113.2  1.24  2024
# 994          16  27  55  0.329  23.0  105.8  112.8 -6.57  2024
# 995          17  22  60  0.268  28.0  112.1  118.6 -5.80  2024
#
#                       team
# 0          Boston Celtics*
# 1      Philadelphia 76ers*
# 2         New York Knicks*
# 3       Washington Bullets
# 4          New Jersey Nets
# ..                     ...
# ...

# %%
teams.head(30)
# Out:
#     Unnamed: 0   W   L   W/L%    GB   PS/G   PA/G    SRS  year  \
# 0            1  56  26  0.683     —  111.5  105.7   5.22  1991
# 1            2  44  38  0.537  12.0  105.4  105.6  -0.39  1991
# 2            3  39  43  0.476  17.0  103.1  103.3  -0.43  1991
# 3            4  30  52  0.366  26.0  101.4  106.4  -4.84  1991
# 4            5  26  56  0.317  30.0  102.9  107.5  -4.53  1991
# 5            6  24  58  0.293  32.0  101.8  107.8  -5.91  1991
# 6            8  61  21  0.744     —  110.0  101.0   8.57  1991
# 7            9  50  32  0.610  11.0  100.1   96.8   3.08  1991
# 8           10  48  34  0.585  13.0  106.4  104.0   2.33  1991
# 9           11  43  39  0.524  18.0  109.8  109.0   0.72  1991
# 10          12  41  41  0.500  20.0  111.7  112.1  -0.37  1991
# 11          13  33  49  0.402  28.0  101.7  104.2  -2.33  1991
# 12          14  26  56  0.317  35.0  102.8  108.0  -4.95  1991
# 13           1  55  27  0.671     —  107.1  102.6   4.30  1991
# ...

# %%
# if there is string that contain division get rid of that (using negation, so dont have to use if else)
teams = teams[~teams['W'].str.contains('Division')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[125], line 2
#       1 # if there is string that contain division get rid of that (using negation, so dont have to use if else)
# ----> 2 teams = teams[~teams['W'].str.contains('Division')]
#
# File d:\software\New folder\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File d:\software\New folder\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
teams
# Out:
#      Unnamed: 0   W   L   W/L%    GB   PS/G   PA/G   SRS  year  \
# 0             1  56  26  0.683     —  111.5  105.7  5.22  1991
# 1             2  44  38  0.537  12.0  105.4  105.6 -0.39  1991
# 2             3  39  43  0.476  17.0  103.1  103.3 -0.43  1991
# 3             4  30  52  0.366  26.0  101.4  106.4 -4.84  1991
# 4             5  26  56  0.317  30.0  102.9  107.5 -4.53  1991
# ..          ...  ..  ..    ...   ...    ...    ...   ...   ...
# 991          13  50  32  0.610     —  117.9  115.6  2.30  2024
# 992          14  49  33  0.598   1.0  115.1  110.7  4.46  2024
# 993          15  41  41  0.500   9.0  114.3  113.2  1.24  2024
# 994          16  27  55  0.329  23.0  105.8  112.8 -6.57  2024
# 995          17  22  60  0.268  28.0  112.1  118.6 -5.80  2024
#
#                       team
# 0          Boston Celtics*
# 1      Philadelphia 76ers*
# 2         New York Knicks*
# 3       Washington Bullets
# 4          New Jersey Nets
# ..                     ...
# ...

# %%
teams.head(30)
# Out:
#     Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G     SRS  year  \
# 1            1  56  26  .683     —  111.5  105.7    5.22  1991
# 2            2  44  38  .537  12.0  105.4  105.6   -0.39  1991
# 3            3  39  43  .476  17.0  103.1  103.3   -0.43  1991
# 4            4  30  52  .366  26.0  101.4  106.4   -4.84  1991
# 5            5  26  56  .317  30.0  102.9  107.5   -4.53  1991
# 6            6  24  58  .293  32.0  101.8  107.8   -5.91  1991
# 8            8  61  21  .744     —  110.0  101.0    8.57  1991
# 9            9  50  32  .610  11.0  100.1   96.8    3.08  1991
# 10          10  48  34  .585  13.0  106.4  104.0    2.33  1991
# 11          11  43  39  .524  18.0  109.8  109.0    0.72  1991
# 12          12  41  41  .500  20.0  111.7  112.1   -0.37  1991
# 13          13  33  49  .402  28.0  101.7  104.2   -2.33  1991
# 14          14  26  56  .317  35.0  102.8  108.0   -4.95  1991
# 16           1  55  27  .671     —  107.1  102.6    4.30  1991
# ...

# %%
teams['team'] = teams['team'].str.replace('*', '', regex = False)

# %%
teams['team'] = teams['team'].str.replace('*', '', regex = False)
# Out:
# C:\Users\Wahyunan\AppData\Local\Temp\ipykernel_8088\1270220197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teams['team'] = teams['team'].str.replace('*', '', regex = False)

# %%
teams.head()
# Out:
#    Unnamed: 0   W   L   W/L%    GB   PS/G   PA/G   SRS  year  \
# 0           1  56  26  0.683     —  111.5  105.7  5.22  1991
# 1           2  44  38  0.537  12.0  105.4  105.6 -0.39  1991
# 2           3  39  43  0.476  17.0  103.1  103.3 -0.43  1991
# 3           4  30  52  0.366  26.0  101.4  106.4 -4.84  1991
# 4           5  26  56  0.317  30.0  102.9  107.5 -4.53  1991
#
#                  team
# 0      Boston Celtics
# 1  Philadelphia 76ers
# 2     New York Knicks
# 3  Washington Bullets
# 4     New Jersey Nets

# %%
teams.head(30)
# Out:
#     Unnamed: 0   W   L   W/L%    GB   PS/G   PA/G    SRS  year  \
# 0            1  56  26  0.683     —  111.5  105.7   5.22  1991
# 1            2  44  38  0.537  12.0  105.4  105.6  -0.39  1991
# 2            3  39  43  0.476  17.0  103.1  103.3  -0.43  1991
# 3            4  30  52  0.366  26.0  101.4  106.4  -4.84  1991
# 4            5  26  56  0.317  30.0  102.9  107.5  -4.53  1991
# 5            6  24  58  0.293  32.0  101.8  107.8  -5.91  1991
# 6            8  61  21  0.744     —  110.0  101.0   8.57  1991
# 7            9  50  32  0.610  11.0  100.1   96.8   3.08  1991
# 8           10  48  34  0.585  13.0  106.4  104.0   2.33  1991
# 9           11  43  39  0.524  18.0  109.8  109.0   0.72  1991
# 10          12  41  41  0.500  20.0  111.7  112.1  -0.37  1991
# 11          13  33  49  0.402  28.0  101.7  104.2  -2.33  1991
# 12          14  26  56  0.317  35.0  102.8  108.0  -4.95  1991
# 13           1  55  27  0.671     —  107.1  102.6   4.30  1991
# ...

# %%
teams.head(30)
# Out:
#     Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G     SRS  year  \
# 1            1  56  26  .683     —  111.5  105.7    5.22  1991
# 2            2  44  38  .537  12.0  105.4  105.6   -0.39  1991
# 3            3  39  43  .476  17.0  103.1  103.3   -0.43  1991
# 4            4  30  52  .366  26.0  101.4  106.4   -4.84  1991
# 5            5  26  56  .317  30.0  102.9  107.5   -4.53  1991
# 6            6  24  58  .293  32.0  101.8  107.8   -5.91  1991
# 8            8  61  21  .744     —  110.0  101.0    8.57  1991
# 9            9  50  32  .610  11.0  100.1   96.8    3.08  1991
# 10          10  48  34  .585  13.0  106.4  104.0    2.33  1991
# 11          11  43  39  .524  18.0  109.8  109.0    0.72  1991
# 12          12  41  41  .500  20.0  111.7  112.1   -0.37  1991
# 13          13  33  49  .402  28.0  101.7  104.2   -2.33  1991
# 14          14  26  56  .317  35.0  102.8  108.0   -4.95  1991
# 16           1  55  27  .671     —  107.1  102.6    4.30  1991
# ...

# %%
teams['team'].unique()
# Out:
# array(['Boston Celtics', 'Philadelphia 76ers', 'New York Knicks',
#        'Brooklyn Nets', 'Toronto Raptors', 'Milwaukee Bucks',
#        'Cleveland Cavaliers', 'Chicago Bulls', 'Indiana Pacers',
#        'Detroit Pistons', 'Miami Heat', 'Atlanta Hawks',
#        'Washington Wizards', 'Orlando Magic', 'Charlotte Hornets',
#        'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Utah Jazz', 'Portland Trail Blazers',
#        'Sacramento Kings', 'Phoenix Suns', 'Los Angeles Clippers',
#        'Golden State Warriors', 'Los Angeles Lakers', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'Dallas Mavericks', 'Houston Rockets',
#        'San Antonio Spurs'], dtype=object)

# %%
combined['Tm'].unique()
# Out:
# array(['MIL', 'DAL', 'ATL', 'DEN', 'HOU', 'IND', 'OKC', 'CHI', 'ORL',
#        'BOS', 'DET', 'NYK', 'CHO', 'SAC', 'SAS', 'BRK', 'MIA', 'LAC',
#        'GSW', 'POR', 'LAL', 'MIN', 'WAS', 'PHO', 'MEM', 'NOP', 'UTA',
#        'TOR', 'PHI', 'CLE'], dtype=object)

# %%
del teams['Unnamed: 0']

# %%
del teams['Unnamed: 0']

# %%
with open('nicknames.csv') as f:
    lines = f.readlines()


lines
# Out:
# ['Team,Abbreviation\n',
#  'Atlanta Hawks,ATL\n',
#  'Boston Celtics,BOS\n',
#  'Brooklyn Nets,BRK\n',
#  'Charlotte Bobcats,CHA\n',
#  'Chicago Bulls,CHI\n',
#  'Cleveland Cavaliers,CLE\n',
#  'Dallas Mavericks,DAL\n',
#  'Denver Nuggets,DEN\n',
#  'Detroit Pistons,DET\n',
#  'Golden State Warriors,GSW\n',
#  'Houston Rockets,HOU\n',
#  'Indiana Pacers,IND\n',
#  'Los Angeles Clippers,LAC\n',
#  'Los Angeles Lakers,LAL\n',
#  'Memphis Grizzlies,MEM\n',
#  'Miami Heat,MIA\n',
#  'Milwaukee Bucks,MIL\n',
#  'Minnesota Timberwolves,MIN\n',
#  'New Orleans Pelicans,NOP\n',
#  'New York Knicks,NYK\n',
#  'Oklahoma City Thunder,OKC\n',
#  'Orlando Magic,ORL\n',
#  'Philadelphia 76ers,PHI\n',
#  'Portland Trail Blazers,POR\n',
#  'Sacramento Kings,SAC\n',
#  'San Antonio Spurs,SAS\n',
#  'Toronto Raptors,TOR\n',
#  'Utah Jazz,UTA\n',
#  'Washington Wizards,WAS\n',
#  'Phoenix Suns,PHO\n',
#  'Washington Bullets,WSB\n',
#  'New Orleans Hornets,NOH\n',
#  'Charlotte Hornets,CHO\n',
# ...

# %%
with open('nicknames.csv') as f:
    lines = f.readlines()


lines
# Out:
# ['Team,Abbreviation\n',
#  'Atlanta Hawks,ATL\n',
#  'Boston Celtics,BOS\n',
#  'Brooklyn Nets,BRK\n',
#  'Charlotte Bobcats,CHA\n',
#  'Chicago Bulls,CHI\n',
#  'Cleveland Cavaliers,CLE\n',
#  'Dallas Mavericks,DAL\n',
#  'Denver Nuggets,DEN\n',
#  'Detroit Pistons,DET\n',
#  'Golden State Warriors,GSW\n',
#  'Houston Rockets,HOU\n',
#  'Indiana Pacers,IND\n',
#  'Los Angeles Clippers,LAC\n',
#  'Los Angeles Lakers,LAL\n',
#  'Memphis Grizzlies,MEM\n',
#  'Miami Heat,MIA\n',
#  'Milwaukee Bucks,MIL\n',
#  'Minnesota Timberwolves,MIN\n',
#  'New Orleans Pelicans,NOP\n',
#  'New York Knicks,NYK\n',
#  'Oklahoma City Thunder,OKC\n',
#  'Orlando Magic,ORL\n',
#  'Philadelphia 76ers,PHI\n',
#  'Portland Trail Blazers,POR\n',
#  'Sacramento Kings,SAC\n',
#  'San Antonio Spurs,SAS\n',
#  'Toronto Raptors,TOR\n',
#  'Utah Jazz,UTA\n',
#  'Washington Wizards,WAS\n',
#  'Phoenix Suns,PHO\n',
#  'Washington Bullets,WSB\n',
#  'New Orleans Hornets,NOH\n',
#  'Charlotte Hornets,CHO\n',
# ...

# %%
nicknames = {}

with open('nicknames.csv') as f:
    lines = f.readlines()

    for line in lines[1:]: #skipping the first row coz its the tittle
        Team, Abbreviation  = line.replace('\n','').split(',')
        nicknames[Abbreviation] = Team

# %%
nicknames
# Out:
# {'ATL': 'Atlanta Hawks',
#  'BOS': 'Boston Celtics',
#  'BRK': 'Brooklyn Nets',
#  'CHA': 'Charlotte Bobcats',
#  'CHI': 'Chicago Bulls',
#  'CLE': 'Cleveland Cavaliers',
#  'DAL': 'Dallas Mavericks',
#  'DEN': 'Denver Nuggets',
#  'DET': 'Detroit Pistons',
#  'GSW': 'Golden State Warriors',
#  'HOU': 'Houston Rockets',
#  'IND': 'Indiana Pacers',
#  'LAC': 'Los Angeles Clippers',
#  'LAL': 'Los Angeles Lakers',
#  'MEM': 'Memphis Grizzlies',
#  'MIA': 'Miami Heat',
#  'MIL': 'Milwaukee Bucks',
#  'MIN': 'Minnesota Timberwolves',
#  'NOP': 'New Orleans Pelicans',
#  'NYK': 'New York Knicks',
#  'OKC': 'Oklahoma City Thunder',
#  'ORL': 'Orlando Magic',
#  'PHI': 'Philadelphia 76ers',
#  'POR': 'Portland Trail Blazers',
#  'SAC': 'Sacramento Kings',
#  'SAS': 'San Antonio Spurs',
#  'TOR': 'Toronto Raptors',
#  'UTA': 'Utah Jazz',
#  'WAS': 'Washington Wizards',
#  'PHO': 'Phoenix Suns',
#  'WSB': 'Washington Bullets',
#  'NOH': 'New Orleans Hornets',
#  'CHO': 'Charlotte Hornets',
# ...

# %%
combined['team'] = combined['Tm'].map(nicknames)

# %%
combined['team'] = combined['Tm'].map(nicknames)

# %%
combined.head(5)
# Out:
#         Player  Age   Tm Pos   G  GS    MP   FG  FGA    FG%  ...  STL  BLK  \
# 0   A.J. Green   23  MIL  SG  35   1   9.9  1.5  3.6  0.424  ...  0.2  0.0
# 1   A.J. Green   24  MIL  SG  56   0  11.0  1.5  3.5  0.423  ...  0.2  0.1
# 2  A.J. Lawson   22  DAL  SG  15   0   7.2  1.5  2.9  0.500  ...  0.1  0.0
# 3  A.J. Lawson   23  DAL  SG  42   0   7.4  1.3  2.9  0.446  ...  0.2  0.1
# 4   AJ Griffin   19  ATL  SF  72  12  19.5  3.4  7.4  0.465  ...  0.6  0.2
#
#    TOV   PF  PTS  year  Pts Won  Pts Max  Share              team
# 0  0.3  0.9  4.4  2023      0.0      0.0    0.0   Milwaukee Bucks
# 1  0.2  0.9  4.5  2024      0.0      0.0    0.0   Milwaukee Bucks
# 2  0.2  0.7  3.7  2023      0.0      0.0    0.0  Dallas Mavericks
# 3  0.3  0.5  3.2  2024      0.0      0.0    0.0  Dallas Mavericks
# 4  0.6  1.2  8.9  2023      0.0      0.0    0.0     Atlanta Hawks
#
# [5 rows x 34 columns]

# %%
combined.head(5)
# Out:
#         Player  Age   Tm Pos   G  GS    MP   FG  FGA    FG%  ...  STL  BLK  \
# 0   A.J. Green   23  MIL  SG  35   1   9.9  1.5  3.6  0.424  ...  0.2  0.0
# 1   A.J. Green   24  MIL  SG  56   0  11.0  1.5  3.5  0.423  ...  0.2  0.1
# 2  A.J. Lawson   22  DAL  SG  15   0   7.2  1.5  2.9  0.500  ...  0.1  0.0
# 3  A.J. Lawson   23  DAL  SG  42   0   7.4  1.3  2.9  0.446  ...  0.2  0.1
# 4   AJ Griffin   19  ATL  SF  72  12  19.5  3.4  7.4  0.465  ...  0.6  0.2
#
#    TOV   PF  PTS  year  Pts Won  Pts Max  Share              team
# 0  0.3  0.9  4.4  2023      0.0      0.0    0.0   Milwaukee Bucks
# 1  0.2  0.9  4.5  2024      0.0      0.0    0.0   Milwaukee Bucks
# 2  0.2  0.7  3.7  2023      0.0      0.0    0.0  Dallas Mavericks
# 3  0.3  0.5  3.2  2024      0.0      0.0    0.0  Dallas Mavericks
# 4  0.6  1.2  8.9  2023      0.0      0.0    0.0     Atlanta Hawks
#
# [5 rows x 34 columns]

# %%
combined.head(5)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  STL  BLK  TOV  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.7  0.3  1.2
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.1  0.4  1.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.1  0.5  1.4
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.9  0.5  1.2
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  0.7  0.4  1.4
#
#     PF   PTS  year Pts Won Pts Max Share                team
# 0  1.4   9.1  1991     0.0     0.0   0.0  Los Angeles Lakers
# 1  1.7  13.6  1992     0.0     0.0   0.0  Los Angeles Lakers
# 2  1.8  12.8  1993     0.0     0.0   0.0  Los Angeles Lakers
# 3  1.7  14.7  1994     0.0     0.0   0.0        Phoenix Suns
# 4  1.8  11.2  1995     0.0     0.0   0.0        Phoenix Suns
#
# [5 rows x 34 columns]

# %%
# combined.isna().sum()

# %%
# combined['team'].unique()

# %%
# team_team = teams['team'].unique()
# combined_team = combined['team'].unique()
# len(team_team)
# len(combined_team)
# tm_temp = []
# for tm in team_team:
#     if tm not in combined_team:
#         tm_temp.append(tm)

# %%
# print(tm_temp)

# %%
teams['team'].unique()
# Out:
# array(['Boston Celtics', 'Philadelphia 76ers', 'New York Knicks',
#        'Washington Bullets', 'New Jersey Nets', 'Miami Heat',
#        'Chicago Bulls', 'Detroit Pistons', 'Milwaukee Bucks',
#        'Atlanta Hawks', 'Indiana Pacers', 'Cleveland Cavaliers',
#        'Charlotte Hornets', 'San Antonio Spurs', 'Utah Jazz',
#        'Houston Rockets', 'Orlando Magic', 'Minnesota Timberwolves',
#        'Dallas Mavericks', 'Denver Nuggets', 'Portland Trail Blazers',
#        'Los Angeles Lakers', 'Phoenix Suns', 'Golden State Warriors',
#        'Seattle SuperSonics', 'Los Angeles Clippers', 'Sacramento Kings',
#        'Toronto Raptors', 'Vancouver Grizzlies', 'Washington Wizards',
#        'Memphis Grizzlies', 'New Orleans Hornets', 'Charlotte Bobcats',
#        'New Orleans/Oklahoma City Hornets', 'Oklahoma City Thunder',
#        'Brooklyn Nets', 'New Orleans Pelicans'], dtype=object)

# %%
teams['team'].unique()
# Out:
# array(['Boston Celtics', 'Philadelphia 76ers', 'New York Knicks',
#        'Washington Bullets', 'New Jersey Nets', 'Miami Heat',
#        'Chicago Bulls', 'Detroit Pistons', 'Milwaukee Bucks',
#        'Atlanta Hawks', 'Indiana Pacers', 'Cleveland Cavaliers',
#        'Charlotte Hornets', 'San Antonio Spurs', 'Utah Jazz',
#        'Houston Rockets', 'Orlando Magic', 'Minnesota Timberwolves',
#        'Dallas Mavericks', 'Denver Nuggets', 'Portland Trail Blazers',
#        'Los Angeles Lakers', 'Phoenix Suns', 'Golden State Warriors',
#        'Seattle SuperSonics', 'Los Angeles Clippers', 'Sacramento Kings',
#        'Toronto Raptors', 'Vancouver Grizzlies', 'Washington Wizards',
#        'Memphis Grizzlies', 'New Orleans Hornets', 'Charlotte Bobcats',
#        'New Orleans/Oklahoma City Hornets', 'Oklahoma City Thunder',
#        'Brooklyn Nets', 'New Orleans Pelicans'], dtype=object)

# %%
combined.shape
# Out:
# (1111, 34)

# %%
combined.shape
# Out:
# (15808, 34)

# %%
teams
# Out:
#      W   L   W/L%    GB   PS/G   PA/G    SRS  year                    team
# 0   57  25  0.695     —  117.9  111.4   6.38  2023          Boston Celtics
# 1   54  28  0.659   3.0  115.2  110.9   4.37  2023      Philadelphia 76ers
# 2   47  35  0.573  10.0  116.0  113.1   2.99  2023         New York Knicks
# 3   45  37  0.549  12.0  113.4  112.5   1.03  2023           Brooklyn Nets
# 4   41  41  0.500  16.0  112.9  111.4   1.59  2023         Toronto Raptors
# 5   58  24  0.707     —  116.9  113.3   3.61  2023         Milwaukee Bucks
# 6   51  31  0.622   7.0  112.3  106.9   5.23  2023     Cleveland Cavaliers
# 7   40  42  0.488  18.0  113.1  111.8   1.37  2023           Chicago Bulls
# 8   35  47  0.427  23.0  116.3  119.5  -2.91  2023          Indiana Pacers
# 9   17  65  0.207  41.0  110.3  118.5  -7.73  2023         Detroit Pistons
# 10  44  38  0.537     —  109.5  109.8  -0.13  2023              Miami Heat
# ...

# %%
stats = combined.merge(teams, how='outer',on=(['team', 'year']))

# %%
stats
# Out:
#                    Player  Age   Tm Pos   G  GS    MP   FG   FGA    FG%  ...  \
# 0              AJ Griffin   19  ATL  SF  72  12  19.5  3.4   7.4  0.465  ...
# 1           Aaron Holiday   26  ATL  PG  63   6  13.4  1.5   3.5  0.418  ...
# 2       Bogdan Bogdanović   30  ATL  SG  54   9  27.9  5.1  11.3  0.447  ...
# 3          Bruno Fernando   24  ATL   C  39   4  10.4  1.5   2.9  0.527  ...
# 4            Clint Capela   28  ATL   C  65  63  26.6  5.4   8.2  0.653  ...
# ...                   ...  ...  ...  ..  ..  ..   ...  ...   ...    ...  ...
# 1106    Marvin Bagley III   24  WAS   C  50  25  21.1  4.8   8.2  0.586  ...
# 1107  Patrick Baldwin Jr.   21  WAS  SF  38   7  13.0  1.6   4.1  0.381  ...
# 1108       Richaun Holmes   30  WAS   C  40  10  13.9  2.1   3.7  0.558  ...
# 1109     Tristan Vukcevic   20  WAS   C  10   4  15.3  2.9   6.7  0.433  ...
# 1110           Tyus Jones   27  WAS  PG  66  66  29.3  4.9  10.1  0.489  ...
#
# ...

# %%
stats = combined.merge(teams, how='outer',on=(['team', 'year']))

# %%
stats.tail(100)
# Out:
#                    Player  Age   Tm Pos   G  GS    MP   FG   FGA    FG%  ...  \
# 1011          Will Barton   32  TOR  SG  56   2  17.7  2.5   6.5  0.379  ...
# 1012          Bruce Brown   27  TOR  SG  67  44  27.9  4.1   8.7  0.478  ...
# 1013        Chris Boucher   31  TOR  PF  50   0  14.1  2.2   4.3  0.507  ...
# 1014          D.J. Carton   23  TOR  SG   4   0   9.0  0.8   2.0  0.375  ...
# 1015       Garrett Temple   37  TOR  SG  27   2  10.7  1.1   2.9  0.372  ...
# ...                   ...  ...  ...  ..  ..  ..   ...  ...   ...    ...  ...
# 1106    Marvin Bagley III   24  WAS   C  50  25  21.1  4.8   8.2  0.586  ...
# 1107  Patrick Baldwin Jr.   21  WAS  SF  38   7  13.0  1.6   4.1  0.381  ...
# 1108       Richaun Holmes   30  WAS   C  40  10  13.9  2.1   3.7  0.558  ...
# 1109     Tristan Vukcevic   20  WAS   C  10   4  15.3  2.9   6.7  0.433  ...
# 1110           Tyus Jones   27  WAS  PG  66  66  29.3  4.9  10.1  0.489  ...
#
# ...

# %%
stats.tail(100)
# Out:
#                    Player   Age   Tm Pos     G    GS    MP   FG   FGA    FG%  \
# 1947             Rudy Gay  36.0  UTA  PF  56.0   0.0  14.6  1.9   5.1  0.380
# 1948    Simone Fontecchio  27.0  UTA  SF  52.0   6.0  14.7  2.2   6.0  0.369
# 1949  Talen Horton-Tucker  22.0  UTA  SG  65.0  20.0  20.2  4.0   9.4  0.419
# 1950       Udoka Azubuike  23.0  UTA   C  36.0   4.0  10.0  1.6   2.0  0.819
# 1951       Walker Kessler  21.0  UTA   C  74.0  40.0  23.0  4.0   5.6  0.720
# ...                   ...   ...  ...  ..   ...   ...   ...  ...   ...    ...
# 2042    Marvin Bagley III  24.0  WAS   C  50.0  25.0  21.1  4.8   8.2  0.586
# 2043  Patrick Baldwin Jr.  21.0  WAS  SF  38.0   7.0  13.0  1.6   4.1  0.381
# 2044       Richaun Holmes  30.0  WAS   C  40.0  10.0  13.9  2.1   3.7  0.558
# 2045     Tristan Vukcevic  20.0  WAS   C  10.0   4.0  15.3  2.9   6.7  0.433
# 2046           Tyus Jones  27.0  WAS  PG  66.0  66.0  29.3  4.9  10.1  0.489
#
# ...

# %%
stats = combined.merge(teams, how='outer',on=(['team', 'year']))

# %%
stats.tail(100)
# Out:
#                    Player   Age   Tm Pos     G    GS    MP   FG   FGA    FG%  \
# 1947             Rudy Gay  36.0  UTA  PF  56.0   0.0  14.6  1.9   5.1  0.380
# 1948    Simone Fontecchio  27.0  UTA  SF  52.0   6.0  14.7  2.2   6.0  0.369
# 1949  Talen Horton-Tucker  22.0  UTA  SG  65.0  20.0  20.2  4.0   9.4  0.419
# 1950       Udoka Azubuike  23.0  UTA   C  36.0   4.0  10.0  1.6   2.0  0.819
# 1951       Walker Kessler  21.0  UTA   C  74.0  40.0  23.0  4.0   5.6  0.720
# ...                   ...   ...  ...  ..   ...   ...   ...  ...   ...    ...
# 2042    Marvin Bagley III  24.0  WAS   C  50.0  25.0  21.1  4.8   8.2  0.586
# 2043  Patrick Baldwin Jr.  21.0  WAS  SF  38.0   7.0  13.0  1.6   4.1  0.381
# 2044       Richaun Holmes  30.0  WAS   C  40.0  10.0  13.9  2.1   3.7  0.558
# 2045     Tristan Vukcevic  20.0  WAS   C  10.0   4.0  15.3  2.9   6.7  0.433
# 2046           Tyus Jones  27.0  WAS  PG  66.0  66.0  29.3  4.9  10.1  0.489
#
# ...

# %%
stats.shape
# Out:
# (1111, 41)

# %%
stats.shape
# Out:
# (15808, 41)

# %%
stats.dtypes
# Out:
# Player      object
# Age          int64
# Tm          object
# Pos         object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# team        object
# W            int64
# L            int64
# W/L%       float64
# GB          object
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age         object
# Tm          object
# G           object
# GS          object
# MP          object
# FG          object
# FGA         object
# FG%         object
# 3P          object
# 3PA         object
# 3P%         object
# 2P          object
# 2PA         object
# 2P%         object
# eFG%        object
# FT          object
# FTA         object
# FT%         object
# ORB         object
# DRB         object
# TRB         object
# AST         object
# STL         object
# BLK         object
# TOV         object
# PF          object
# PTS         object
# year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# team        object
# W           object
# L           object
# W/L%        object
# GB          object
# PS/G        object
# PA/G        object
# SRS         object
# dtype: object

# %% [markdown]
# convert all type to numeeric, make it easier when traiing the data

# %%
stats = stats.apply(pd.to_numeric, errors='ignore')
# Out:
# C:\Users\Wahyunan\AppData\Local\Temp\ipykernel_26064\3935204516.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   stats = stats.apply(pd.to_numeric, errors='ignore')

# %%
stats = stats.apply(pd.to_numeric, errors='ignore')
# Out:
# C:\Users\Wahyunan\AppData\Local\Temp\ipykernel_20272\3935204516.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   stats = stats.apply(pd.to_numeric, errors='ignore')

# %%
stats.dtypes
# Out:
# Player      object
# Age        float64
# Tm          object
# Pos         object
# G          float64
# GS         float64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# team        object
# W            int64
# L            int64
# W/L%       float64
# GB          object
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats = stats.apply(pd.to_numeric, errors='ignore')

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# team        object
# W            int64
# L            int64
# W/L%       float64
# GB          object
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats['GB'].unique()
# Out:
# array(['3.0', '11.0', '—', '12.0', '32.0', '17.0', '26.0', '18.0', '10.0',
#        '7.0', '1.0', '13.0', '41.0', '35.0', '4.0', '5.0', '29.0', '9.0',
#        '23.0', '2.0', '14.0', '20.0', '36.0', '28.0', '16.0', '39.0'],
#       dtype=object)

# %%
stats['GB'].unique()
# Out:
# array(['5.0', '14.0', '23.0', '7.0', '—', '40.0', '42.0', '18.0', '6.0',
#        '24.0', '26.0', '37.0', '29.0', '21.0', '28.0', '13.0', '25.0',
#        '8.0', '19.0', '3.0', '11.0', '1.0', '17.0', '15.0', '9.0', '2.0',
#        '35.0', '20.0', '16.0', '41.0', '12.0', '50.0', '10.0', '30.0',
#        '34.0', '4.0', '1.5', '22.0', '51.0', '36.0', '43.0', '39.0',
#        '18.5', '31.0', '48.0', '46.0', '10.5', '32.0', '38.0', '27.0',
#        '33.0', '21.5', '45.0', '22.5', '25.5', '3.5', '20.5', '11.5',
#        '44.0', '52.0', '56.0', '2.5', '12.5', '47.0', '32.5', '4.5'],
#       dtype=object)

# %%
stats['GB'] = stats['GB'].str.replace('—', '0')

# %%
stats['GB'].unique()
# Out:
# array(['3.0', '11.0', '0', '12.0', '32.0', '17.0', '26.0', '18.0', '10.0',
#        '7.0', '1.0', '13.0', '41.0', '35.0', '4.0', '5.0', '29.0', '9.0',
#        '23.0', '2.0', '14.0', '20.0', '36.0', '28.0', '16.0', '39.0'],
#       dtype=object)

# %%
stats['GB'] = pd.to_numeric(stats['GB'])

# %%
stats.dtypes
# Out:
# Player      object
# Age          int64
# Tm          object
# Pos         object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# team        object
# W            int64
# L            int64
# W/L%       float64
# GB         float64
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# team        object
# W            int64
# L            int64
# W/L%       float64
# GB         float64
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats.shape
# Out:
# (2047, 41)

# %%
stats.shape
# Out:
# (15808, 41)

# %%
stats.columns
# Out:
# Index(['Player', 'Age', 'Tm', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year',
#        'Pts Won', 'Pts Max', 'Share', 'team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year',
#        'Pts Won', 'Pts Max', 'Share', 'team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
advanced_stat = pd.read_csv('player_stats_1991_2024.csv')

# %%
advanced_stat
# Out:
#        Rk             Player  Age Team Pos   G  GS    MP   PER    TS%  ...  \
# 0       1      Mikal Bridges   26  2TM  SG  83  83  2963  16.8  0.587  ...
# 1       2      Mikal Bridges   26  PHO  SF  56  56  2040  14.8  0.574  ...
# 2       3      Mikal Bridges   26  BRK  SG  27  27   923  21.3  0.607  ...
# 3       4    Anthony Edwards   21  MIN  SG  79  79  2842  17.4  0.564  ...
# 4       5        Zach LaVine   27  CHI  SG  77  77  2768  19.0  0.607  ...
# ...   ...                ...  ...  ...  ..  ..  ..   ...   ...    ...  ...
# 1409  731    Malcolm Cazalon   22  DET  SG   1   0     3   0.0    NaN  ...
# 1410  732     Jalen Crutcher   24  NOP  PG   1   0     3 -12.6  0.000  ...
# 1411  733  Dmytro Skapintsev   25  NYK   C   2   0     2 -19.3  0.000  ...
# 1412  734     Justin Jackson   28  MIN  SF   2   0     1   0.0    NaN  ...
# 1413  735      Javonte Smart   24  PHI  PG   1   0     1   0.0    NaN  ...
#
#       OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP  Awards  year
# ...

# %%
advanced_stat
# Out:
#        Rk             Player  Age Team Pos   G  GS    MP   PER    TS%  ...  \
# 0       1      Mikal Bridges   26  2TM  SG  83  83  2963  16.8  0.587  ...
# 1       2      Mikal Bridges   26  PHO  SF  56  56  2040  14.8  0.574  ...
# 2       3      Mikal Bridges   26  BRK  SG  27  27   923  21.3  0.607  ...
# 3       4    Anthony Edwards   21  MIN  SG  79  79  2842  17.4  0.564  ...
# 4       5        Zach LaVine   27  CHI  SG  77  77  2768  19.0  0.607  ...
# ...   ...                ...  ...  ...  ..  ..  ..   ...   ...    ...  ...
# 1409  731    Malcolm Cazalon   22  DET  SG   1   0     3   0.0    NaN  ...
# 1410  732     Jalen Crutcher   24  NOP  PG   1   0     3 -12.6  0.000  ...
# 1411  733  Dmytro Skapintsev   25  NYK   C   2   0     2 -19.3  0.000  ...
# 1412  734     Justin Jackson   28  MIN  SF   2   0     1   0.0    NaN  ...
# 1413  735      Javonte Smart   24  PHI  PG   1   0     1   0.0    NaN  ...
#
#       OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP  Awards  year
# ...

# %%
del advanced_stat['Unnamed: 24']

# %%
del advanced_stat['Unnamed: 19']

# %%
del advanced_stat['Rk']

# %%
del advanced_stat['Awards']

# %%
advanced_stat.rename(columns={'Team':'Tm'},inplace=True)

# %%
advanced_stat
# Out:
#                  Player  Age   Tm Pos   G  GS    MP   PER    TS%   3PAr  ...  \
# 0         Mikal Bridges   26  2TM  SG  83  83  2963  16.8  0.587  0.349  ...
# 1         Mikal Bridges   26  PHO  SF  56  56  2040  14.8  0.574  0.342  ...
# 2         Mikal Bridges   26  BRK  SG  27  27   923  21.3  0.607  0.360  ...
# 3       Anthony Edwards   21  MIN  SG  79  79  2842  17.4  0.564  0.375  ...
# 4           Zach LaVine   27  CHI  SG  77  77  2768  19.0  0.607  0.392  ...
# ...                 ...  ...  ...  ..  ..  ..   ...   ...    ...    ...  ...
# 1409    Malcolm Cazalon   22  DET  SG   1   0     3   0.0    NaN    NaN  ...
# 1410     Jalen Crutcher   24  NOP  PG   1   0     3 -12.6  0.000  0.000  ...
# 1411  Dmytro Skapintsev   25  NYK   C   2   0     2 -19.3  0.000  0.000  ...
# 1412     Justin Jackson   28  MIN  SF   2   0     1   0.0    NaN    NaN  ...
# 1413      Javonte Smart   24  PHI  PG   1   0     1   0.0    NaN    NaN  ...
#
# ...

# %%
advanced_stat.columns
# Out:
# Index(['Player', 'Age', 'Tm', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'year'],
#       dtype='object')

# %%
advanced_stat.columns = advanced_stat.columns.str.replace(r'\.33$', '', regex=True)

# %%
advanced_stat.head(50)
# Out:
#                       Player  Age   Tm Pos   G  GS    MP   PER    TS%   3PAr  \
# 0              Mikal Bridges   26  2TM  SG  83  83  2963  16.8  0.587  0.349
# 1              Mikal Bridges   26  PHO  SF  56  56  2040  14.8  0.574  0.342
# 2              Mikal Bridges   26  BRK  SG  27  27   923  21.3  0.607  0.360
# 3            Anthony Edwards   21  MIN  SG  79  79  2842  17.4  0.564  0.375
# 4                Zach LaVine   27  CHI  SG  77  77  2768  19.0  0.607  0.392
# 5             Nikola Vučević   32  CHI   C  82  82  2746  19.1  0.594  0.302
# 6              Julius Randle   28  NYK  PF  77  77  2737  20.3  0.581  0.444
# 7           Domantas Sabonis   26  SAC   C  79  79  2736  23.5  0.668  0.088
# 8               Jayson Tatum   24  BOS  SF  74  74  2732  23.7  0.607  0.440
# 9          Spencer Dinwiddie   29  2TM  SG  79  79  2725  16.0  0.573  0.467
# 10         Spencer Dinwiddie   29  DAL  SG  53  53  1808  16.1  0.599  0.491
# ...

# %%
advanced_stat['Player'] = advanced_stat['Player'].str.replace('*', "", regex=False)

# %%
advanced_stat['Player'] = advanced_stat['Player'].str.replace('*', "", regex=False)

# %%
advanced_stat = advanced_stat.groupby(['Player', 'year']).apply(single_row)
# Out:
# C:\Users\Wahyunan\AppData\Local\Temp\ipykernel_26064\1453242689.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   advanced_stat = advanced_stat.groupby(['Player', 'year']).apply(single_row)

# %%
advanced_stat = advanced_stat.groupby(['Player', 'year']).apply(single_row)

# %%
advanced_stat.index = advanced_stat.index.droplevel()

# %%
advanced_stat.index = advanced_stat.index.droplevel()

# %%
advanced_stat[pd.isna(advanced_stat['PER'])]
# Out:
# Empty DataFrame
# Columns: [Player, Age, Tm, Pos, G, GS, MP, PER, TS%, 3PAr, FTr, ORB%, DRB%, TRB%, AST%, STL%, BLK%, TOV%, USG%, OWS, DWS, WS, WS/48, OBPM, DBPM, BPM, VORP, year]
# Index: []
#
# [0 rows x 28 columns]

# %%
advanced_stat[pd.isna(advanced_stat['PER'])]
# Out:
#               Player Pos  Age   Tm  G  MP  PER  TS%  3PAr  FTr  ...  USG%  \
# 8082     Alex Scales  SG   27  SAS  1   0  NaN  NaN   NaN  NaN  ...   NaN
# 11904   Damion James  SF   25  BRK  2   0  NaN  NaN   NaN  NaN  ...   NaN
# 10015  JamesOn Curry  PG   24  LAC  1   0  NaN  NaN   NaN  NaN  ...   NaN
#
#        OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP  year
# 8082   0.0  0.0  0.0    NaN  -5.0  -0.7  -5.7   0.0  2006
# 11904  0.0  0.0  0.0    NaN  -3.8  17.8  14.0   0.0  2013
# 10015  0.0  0.0  0.0    NaN  -6.4  -0.6  -7.0   0.0  2010
#
# [3 rows x 27 columns]

# %%
advanced_stat[pd.isna(advanced_stat['WS/48'])]
# Out:
#               Player Pos  Age   Tm  G  MP  PER  TS%  3PAr  FTr  ...  USG%  \
# 8082     Alex Scales  SG   27  SAS  1   0  NaN  NaN   NaN  NaN  ...   NaN
# 11904   Damion James  SF   25  BRK  2   0  NaN  NaN   NaN  NaN  ...   NaN
# 10015  JamesOn Curry  PG   24  LAC  1   0  NaN  NaN   NaN  NaN  ...   NaN
#
#        OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP  year
# 8082   0.0  0.0  0.0    NaN  -5.0  -0.7  -5.7   0.0  2006
# 11904  0.0  0.0  0.0    NaN  -3.8  17.8  14.0   0.0  2013
# 10015  0.0  0.0  0.0    NaN  -6.4  -0.6  -7.0   0.0  2010
#
# [3 rows x 27 columns]

# %%
advanced_stat[pd.isna(advanced_stat['TS%'])]
# Out:
#                     Player Pos  Age   Tm  G  MP   PER  TS%  3PAr  FTr  ...  \
# 17924           Ade Murkey  SG   24  SAC  1   1   0.0  NaN   NaN  NaN  ...
# 3476       Adrian Caldwell  PF   31  DAL  1   3   0.0  NaN   NaN  NaN  ...
# 8082           Alex Scales  SG   27  SAS  1   0   NaN  NaN   NaN  NaN  ...
# 18850     Alondes Williams  SG   23  BRK  1   5 -20.9  NaN   NaN  NaN  ...
# 5332            Andy Panko  SF   23  ATL  1   1   0.0  NaN   NaN  NaN  ...
# 16931        Ashton Hagans  PG   21  MIN  2   4 -12.4  NaN   NaN  NaN  ...
# 15086            Ben Moore  PF   22  IND  2   9  -2.3  NaN   NaN  NaN  ...
# 846         Billy Thompson  SF   28  GSW  1   1   0.0  NaN   NaN  NaN  ...
# 10979        Brian Skinner   C   34  MIL  2   6   0.0  NaN   NaN  NaN  ...
# 2870           Bruce Bowen  SF   25  MIA  1   1  37.7  NaN   NaN  NaN  ...
# 8077         Bryon Russell  SF   35  DEN  1   3  16.4  NaN   NaN  NaN  ...
# ...

# %%
advanced_stat['PER'] = advanced_stat['PER'].fillna(0)

# %%
advanced_stat['TS%'] = advanced_stat['TS%'].fillna(0)

# %%
advanced_stat['3PAr'] = advanced_stat['3PAr'].fillna(0)

# %%
advanced_stat['FTr'] = advanced_stat['FTr'].fillna(0)

# %%
advanced_stat['ORB%'] = advanced_stat['ORB%'].fillna(0)

# %%
advanced_stat['DRB%'] = advanced_stat['DRB%'].fillna(0)

# %%
advanced_stat['TRB%'] = advanced_stat['TRB%'].fillna(0)

# %%
advanced_stat['AST%'] = advanced_stat['AST%'].fillna(0)

# %%
advanced_stat['STL%'] = advanced_stat['STL%'].fillna(0)

# %%
advanced_stat['BLK%'] = advanced_stat['BLK%'].fillna(0)

# %%
advanced_stat['TOV%'] = advanced_stat['TOV%'].fillna(0)

# %%
advanced_stat['USG%'] = advanced_stat['USG%'].fillna(0)

# %%
advanced_stat['WS/48'] = advanced_stat['WS/48'].fillna(0)

# %%
advanced_stat.columns
# Out:
# Index(['Player', 'Age', 'Tm', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'year'],
#       dtype='object')

# %%
advanced_stat.columns
# Out:
# Index(['Player', 'Age', 'Tm', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'year'],
#       dtype='object')

# %%
advanced_stat
# Out:
#                Player  Age   Tm Pos   G  GS    MP   PER    TS%   3PAr  ...  \
# 513        A.J. Green   23  MIL  SG  35   1   345  11.5  0.607  0.840  ...
# 1107       A.J. Green   24  MIL  SG  56   0   614  10.5  0.617  0.862  ...
# 599       A.J. Lawson   22  DAL  SG  15   0   108  13.9  0.589  0.568  ...
# 1218      A.J. Lawson   23  DAL  SG  42   0   311  11.2  0.519  0.413  ...
# 239        AJ Griffin   19  ATL  SF  72  12  1401  12.6  0.577  0.486  ...
# ...               ...  ...  ...  ..  ..  ..   ...   ...    ...    ...  ...
# 1125       Zeke Nnaji   23  DEN  PF  58   0   576  12.4  0.528  0.154  ...
# 453   Ziaire Williams   21  MEM  SF  37   4   561   7.4  0.511  0.495  ...
# 992   Ziaire Williams   22  MEM  SF  51  15  1038   9.3  0.511  0.500  ...
# 339   Zion Williamson   22  NOP  PF  29  29   956  25.2  0.652  0.041  ...
# 753   Zion Williamson   23  NOP  PF  70  70  2207  22.8  0.610  0.016  ...
#
#       USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP  year
# ...

# %%
advanced_stat
# Out:
#                Player  Age   Tm Pos   G  GS    MP   PER    TS%   3PAr  ...  \
# 513        A.J. Green   23  MIL  SG  35   1   345  11.5  0.607  0.840  ...
# 1107       A.J. Green   24  MIL  SG  56   0   614  10.5  0.617  0.862  ...
# 599       A.J. Lawson   22  DAL  SG  15   0   108  13.9  0.589  0.568  ...
# 1218      A.J. Lawson   23  DAL  SG  42   0   311  11.2  0.519  0.413  ...
# 239        AJ Griffin   19  ATL  SF  72  12  1401  12.6  0.577  0.486  ...
# ...               ...  ...  ...  ..  ..  ..   ...   ...    ...    ...  ...
# 1125       Zeke Nnaji   23  DEN  PF  58   0   576  12.4  0.528  0.154  ...
# 453   Ziaire Williams   21  MEM  SF  37   4   561   7.4  0.511  0.495  ...
# 992   Ziaire Williams   22  MEM  SF  51  15  1038   9.3  0.511  0.500  ...
# 339   Zion Williamson   22  NOP  PF  29  29   956  25.2  0.652  0.041  ...
# 753   Zion Williamson   23  NOP  PF  70  70  2207  22.8  0.610  0.016  ...
#
#       USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP  year
# ...

# %%
advanced_stat.shape
# Out:
# (15808, 27)

# %%
stats.shape
# Out:
# (15808, 41)

# %%
stats.columns
# Out:
# Index(['Player', 'Age', 'Tm', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year',
#        'Pts Won', 'Pts Max', 'Share', 'team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year',
#        'Pts Won', 'Pts Max', 'Share', 'team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
advanced_stat.columns
# Out:
# Index(['Player', 'Age', 'Tm', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'year'],
#       dtype='object')

# %%
advanced_stat.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'TMP', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'year'],
#       dtype='object')

# %%
stats['FG%'] = stats['FG%'].fillna(0)
stats['3P%'] = stats['3P%'].fillna(0)
stats['2P%'] = stats['2P%'].fillna(0)
stats['eFG%'] = stats['eFG%'].fillna(0)
stats['FT%'] = stats['FT%'].fillna(0)

# %%
stats.columns
# Out:
# Index(['Player', 'Age', 'Tm', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year',
#        'Pts Won', 'Pts Max', 'Share', 'team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
del advanced_stat['GS']

# %%
advanced_stat.columns
# Out:
# Index(['Player', 'Age', 'Tm', 'Pos', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'year'],
#       dtype='object')

# %%
advanced_stat.rename(columns={'MP': 'TMP'}, inplace=True)

# %%
# Convert column names to sets
advanced_stat_columns = set(advanced_stat.columns)
stats_columns = set(stats.columns)

# Find common columns
common_columns = advanced_stat_columns.intersection(stats_columns)
print("Common columns:", common_columns)
# Out:
# Common columns: {'Pos', 'Age', 'Tm', 'year', 'Player', 'G'}

# %%
# Convert column names to sets
advanced_stat_columns = set(advanced_stat.columns)
stats_columns = set(stats.columns)

# Find common columns
common_columns = advanced_stat_columns.intersection(stats_columns)
print("Common columns:", common_columns)
# Out:
# Common columns: {'year', 'Age', 'Tm', 'G', 'Pos', 'Player'}

# %%
# Convert column names to sets
advanced_stat_columns = set(advanced_stat.columns)
stats_columns = set(stats.columns)

# Find common columns
common_columns = advanced_stat_columns.intersection(stats_columns)
print("Common columns:", common_columns)
# Out:
# Common columns: {'Pos', 'year', 'Tm', 'Player', 'Age', 'G'}

# %%
advanced_stat.shape
# Out:
# (1111, 22)

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year',
#        'Pts Won', 'Pts Max', 'Share', 'team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
advanced_stat= advanced_stat[['Player', 'year', 'PER', 'TS%', '3PAr', 'FTr',
       'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
       'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP']]

# %%
final_stats = stats.merge(
    advanced_stat[['Player', 'PER', 'TS%', '3PAr', 'FTr',
                   'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
                   'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'year']],
    on=['Player','year'],
    how='inner'
)

# %%
stats
# Out:
#                    Player  Age   Tm Pos   G  GS    MP   FG   FGA    FG%  ...  \
# 0              AJ Griffin   19  ATL  SF  72  12  19.5  3.4   7.4  0.465  ...
# 1           Aaron Holiday   26  ATL  PG  63   6  13.4  1.5   3.5  0.418  ...
# 2       Bogdan Bogdanović   30  ATL  SG  54   9  27.9  5.1  11.3  0.447  ...
# 3          Bruno Fernando   24  ATL   C  39   4  10.4  1.5   2.9  0.527  ...
# 4            Clint Capela   28  ATL   C  65  63  26.6  5.4   8.2  0.653  ...
# ...                   ...  ...  ...  ..  ..  ..   ...  ...   ...    ...  ...
# 1106    Marvin Bagley III   24  WAS   C  50  25  21.1  4.8   8.2  0.586  ...
# 1107  Patrick Baldwin Jr.   21  WAS  SF  38   7  13.0  1.6   4.1  0.381  ...
# 1108       Richaun Holmes   30  WAS   C  40  10  13.9  2.1   3.7  0.558  ...
# 1109     Tristan Vukcevic   20  WAS   C  10   4  15.3  2.9   6.7  0.433  ...
# 1110           Tyus Jones   27  WAS  PG  66  66  29.3  4.9  10.1  0.489  ...
#
# ...

# %%
# Check for extra spaces or special characters
print("Unique values in advanced_stat['Player'] (with length):")
print(advanced_stat['Player'].apply(lambda x: (x, len(x))).unique())

print("Unique values in stats['Player'] (with length):")
print(stats['Player'].apply(lambda x: (x, len(x))).unique())
# Out:
# Unique values in advanced_stat['Player'] (with length):
# [('A.J. Green', 10) ('A.J. Lawson', 11) ('AJ Griffin', 10)
#  ('Aaron Gordon', 12) ('Aaron Holiday', 13) ('Aaron Nesmith', 13)
#  ('Aaron Wiggins', 13) ('Adam Flagler', 12) ('Adama Sanogo', 12)
#  ('Admiral Schofield', 17) ('Al Horford', 10) ('Alec Burks', 10)
#  ('Aleksej Pokusevski', 18) ('Alex Caruso', 11) ('Alex Fudge', 10)
#  ('Alex Len', 8) ('Alize Johnson', 13) ('Alondes Williams', 16)
#  ('Alperen Şengün', 14) ('Amari Bailey', 12) ('Amen Thompson', 13)
#  ('Amir Coffey', 11) ('Andre Drummond', 14) ('Andre Iguodala', 14)
#  ('Andre Jackson Jr.', 17) ('Andrew Funk', 11) ('Andrew Nembhard', 15)
#  ('Andrew Wiggins', 14) ('Anfernee Simons', 15) ('Anthony Black', 13)
#  ('Anthony Davis', 13) ('Anthony Edwards', 15) ('Anthony Gill', 12)
#  ('Anthony Lamb', 12) ('Armoni Brooks', 13) ('Ashton Hagans', 13)
#  ('Ausar Thompson', 14) ('Austin Reaves', 13) ('Austin Rivers', 13)
# ...

# %%
# Check for extra spaces or special characters
print("Unique values in advanced_stat['Player'] (with length):")
print(advanced_stat['Player'].apply(lambda x: (x, len(x))).unique())

print("Unique values in stats['Player'] (with length):")
print(stats['Player'].apply(lambda x: (x, len(x))).unique())
# Out:
# Unique values in advanced_stat['Player'] (with length):
# [('a.c. green', 10) ('a.j. bramlett', 13) ('a.j. english', 12) ...
#  ('žan tabak', 9) ('žarko čabarkapa', 15) ('željko rebrača', 14)]
# Unique values in stats['Player'] (with length):
# [('a.c. green', 10) ('byron scott', 11) ('elden campbell', 14) ...
#  ('myron brown', 11) ('drew gordon', 11) ('furkan aldemir', 14)]

# %%
stats
# Out:
#                Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0          a.c. green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...
# 1         byron scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...
# 2      elden campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...
# 3       irving thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...
# 4        james worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...
# ...               ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 15803   spencer hawes  PF   28  MIL  54   1  14.8  2.5   5.1  0.484  ...
# 15804     steve novak  PF   33  MIL   8   0   2.8  0.3   0.9  0.286  ...
# 15805  terrence jones  PF   25  MIL  54  12  23.5  4.3   9.1  0.470  ...
# 15806      thon maker   C   19  MIL  57  34   9.9  1.5   3.2  0.459  ...
# 15807      tony snell  SG   25  MIL  80  80  29.2  3.1   6.8  0.455  ...
#
#        Pts Max  Share                team   W   L   W/L%   GB   PS/G   PA/G  \
# ...

# %%
advanced_stat
# Out:
#               Player  year   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  \
# 159       a.c. green  1991  13.8  0.556  0.101  0.557  11.3  16.2  13.8   4.5
# 609       a.c. green  1992  16.7  0.556  0.070  0.569  11.8  18.2  14.9   6.0
# 1051      a.c. green  1993  16.3  0.603  0.065  0.531  11.5  17.3  14.4   5.9
# 1519      a.c. green  1994  17.0  0.555  0.038  0.391  11.1  18.8  15.0   6.9
# 1988      a.c. green  1995  14.2  0.596  0.206  0.556   8.3  20.4  14.3   6.5
# ...              ...   ...   ...    ...    ...    ...   ...   ...   ...   ...
# 5866  željko rebrača  2002  16.2  0.569  0.000  0.468   8.4  20.5  14.5   5.7
# 6347  željko rebrača  2003  14.0  0.596  0.000  0.331   6.5  16.0  11.2   3.6
# 6907  željko rebrača  2004  10.5  0.504  0.000  0.390   9.9  14.6  12.2   4.0
# 7485  željko rebrača  2005  14.0  0.625  0.000  0.363   6.5  16.9  11.9   4.8
# 8057  željko rebrača  2006  10.7  0.592  0.000  0.427   3.8  13.8   9.0   3.5
#
# ...

# %%
final_stats.shape
# Out:
# (1111, 61)

# %%
final_stats.isna().all()
# Out:
# Player    False
# Age       False
# Tm        False
# Pos       False
# G         False
#           ...
# WS/48     False
# OBPM      False
# DBPM      False
# BPM       False
# VORP      False
# Length: 61, dtype: bool

# %%
final_stats.shape
# Out:
# (15150, 61)

# %%
final_stats.columns
# Out:
# Index(['Player', 'Age', 'Tm', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year',
#        'Pts Won', 'Pts Max', 'Share', 'team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%',
#        'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48',
#        'OBPM', 'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %%
desired_order = ['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
                 '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
                 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year', 'PER',
                 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
                 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM',
                 'VORP', 'Pts Won', 'Pts Max', 'Share', 'team', 'W', 'L', 'W/L%', 'GB',
                 'PS/G', 'PA/G', 'SRS']

final_stats = final_stats[desired_order]

# %%
final_stats.columns
# Out:
# Index(['Player', 'Pos_x', 'Age_x', 'Tm', 'G_x', 'GS', 'MP_x', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
#        'year', 'Pts Won', 'Pts Max', 'Share', 'team', 'W', 'L', 'W/L%', 'GB',
#        'PS/G', 'PA/G', 'SRS', 'Pos_y', 'Age_y', 'G_y', 'MP_y', 'PER', 'TS%',
#        '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%',
#        'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %%
advanced_stat.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'year'],
#       dtype='object')

# %%
final_stats.shape
# Out:
# (1111, 61)

# %%
final_stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'year', 'PER',
#        'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
#        'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM',
#        'VORP', 'Pts Won', 'Pts Max', 'Share', 'team', 'W', 'L', 'W/L%', 'GB',
#        'PS/G', 'PA/G', 'SRS'],
#       dtype='object')

# %%
final_stats.shape
# Out:
# (1111, 61)

# %%
final_stats.to_csv('final.csv')

# %%
# final_stats['FG%'] = final_stats['FG%'].fillna(0)
# final_stats['3P%'] = final_stats['3P%'].fillna(0)
# final_stats['2P%'] = final_stats['2P%'].fillna(0)
# final_stats['eFG%'] = final_stats['eFG%'].fillna(0)
# final_stats['FT%'] = final_stats['FT%'].fillna(0)

# %%
# import pandas as pd

# # Increase the number of columns displayed
# pd.set_option('display.max_columns', None)

# # Increase the number of rows displayed
# pd.set_option('display.max_rows', None)

# # Now print the DataFrame or Series again
# print(final_stats.isnull().sum())

# %%
# final_stats.shape

# %%
# stats.to_csv('players_mvp_stats_team.csv')

# %%
# highest_scoring = stats[stats['G']>70].sort_values('PTS', ascending = False).head(10)

# %%
# highest_scoring.plot.bar('Player', 'PTS')

# %%
# highest_scoring_year= stats.groupby('year').apply(lambda x: x.sort_values('PTS', ascending = False).head(1))

# %%
# highest_scoring_year.plot.bar('Player', 'PTS')

# %%
# numerical_df = stats[[col for col in stats.columns if stats[col].dtype in ['int64', 'float64']]]

# %%
# numerical_df.corr()['Share']

# %%
# numerical_df.corr()['Share'].plot.bar()
